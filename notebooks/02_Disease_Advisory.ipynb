# %%
diseases = {
    "Tomato - Early Blight": {
        "Symptoms": "Brown spots on older leaves with concentric rings.",
        "Cause": "Alternaria fungus",
        "Treatment": "Remove infected leaves and spray Mancozeb.",
        "Fertilizer": "NPK 10-10-20"
    },
    "Tomato - Late Blight": {
        "Symptoms": "Dark water-soaked patches on leaves and fruits.",
        "Cause": "Phytophthora infestans",
        "Treatment": "Use Copper fungicide and avoid overhead watering.",
        "Fertilizer": "NPK 12-12-17"
    },
    "Potato - Early Blight": {
        "Symptoms": "Small dark spots with yellow halos.",
        "Cause": "Alternaria solani",
        "Treatment": "Spray Chlorothalonil.",
        "Fertilizer": "NPK 15-15-15"
    },
    "Rice - Blast": {
        "Symptoms": "Diamond-shaped lesions on leaves.",
        "Cause": "Magnaporthe oryzae",
        "Treatment": "Spray Tricyclazole.",
        "Fertilizer": "Urea + Potash"
    },
    "Cotton - Leaf Curl": {
        "Symptoms": "Leaves curl upward with thick veins.",
        "Cause": "Whitefly-transmitted virus",
        "Treatment": "Control whiteflies using Imidacloprid.",
        "Fertilizer": "NPK 20-10-10"
    }
}

# %%
print("Available Diseases:\n")

for i, disease in enumerate(diseases.keys(), 1):
    print(f"{i}. {disease}")
# Out:
# Available Diseases:
#
# 1. Tomato - Early Blight
# 2. Tomato - Late Blight
# 3. Potato - Early Blight
# 4. Rice - Blast
# 5. Cotton - Leaf Curl

# %%
choice = input("Enter disease name: ")
if choice in diseases:
    info = diseases[choice]
    print("\nDisease:", choice)
    print("\nSymptoms:", info["Symptoms"])
    print("\nCause:", info["Cause"])
    print("\nTreatment:", info["Treatment"])
    print("\nRecommended Fertilizer:", info["Fertilizer"])
else:
    print("Disease not found.")
# Out:
# Enter disease name:  Tomato - Early Blight
# Disease: Tomato - Early Blight
#
# Symptoms: Brown spots on older leaves with concentric rings.
#
# Cause: Alternaria fungus
#
# Treatment: Remove infected leaves and spray Mancozeb.
#
# Recommended Fertilizer: NPK 10-10-20
